# %% [markdown]
# <div style="font-size:1.5em">
#     <p>📜 Table des matières:</p>
#     <ul>
#        <li><a href="#nltk">Text Preprocessing with NLTK</a></li>
#        <li>
#           <a href="#spacy">Text Preprocessing with spaCy</a>
#        </li>
#        <li>
#           <a href="#ner">Definig NER for nltk and spacy</a>
#        </li>
#        <li><a href="#comp">Comparing NER before/After preprocessing</a>
#        <li><a href="#param">testing preprocessing filters</a></li>
#        </li>
#     </ul>
# </div>

# %% [markdown]
# <h1 id ="nltk">Text Preprocessing with NLTK</h1>

# %%
#import libraries
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import WhitespaceTokenizer , TreebankWordTokenizer,WordPunctTokenizer,word_tokenize
from nltk.corpus import stopwords
import string
import contractions
from spellchecker import SpellChecker
import re
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
import unicodedata
from langdetect import detect
from itertools import chain , combinations
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('words')
nltk.download('wordnet')

def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

def remove_accented_chars(text):
    new_text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return new_text


def text_preprocessing(text,accented=True,stopw=True,punctuation=True,lowercase=True,lemmatize=True,spelling=True,expand_contraction=True,urls=True):
    if detect(text)=='en':
        stopword =stopwords.words('english')
        lemmatizer = WordNetLemmatizer()
        spell = SpellChecker()
    else :#if lang="french"
        stopword = stopwords.words('french')
        lemmatizer = FrenchLefffLemmatizer()
        spell = SpellChecker(language="fr")
    if lowercase:
        #lowercase the text 
        text = text.lower()
    if urls:
        #remove urls
        text=remove_urls(text)
    #tokenize the text 
    tokens =WhitespaceTokenizer().tokenize(text)
    if expand_contraction:
        #expand contractions
        tokens = [contractions.fix(token) for token in tokens]
    if punctuation:
        #remove punctuation
        tokens = [token for token in tokens if token not in string.punctuation]
    if stopw:
        #remove stopwords
        tokens = [token for token in tokens if token not in stopword]
    if accented:
        tokens = [remove_accented_chars(token) for token in tokens]
    if spelling:
        #spell check:
        tokens = [spell.correction(token) for token in tokens]
    if lemmatize:
        #lemmatization : 
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(word for word in tokens)

    #Some tests:
file = 'C:/Users/PC2/Downloads/test-ex.txt'
f=open(file,'r')
data = f.read()
print(text_preprocessing(data))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC2\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# gisevciconia zero solution objet ordre virement Monsieur habit compte :_rib: 022 222 222 172 22 29576475 53 set agilisys zero solution swift agilamcxxx virer montant 89 250,00 dirais (quatre-vingt-neuf mille deux cent cinquante dirais de profit i parler export switzerland ian chez 0483 555 555 0266600 0 swift creschzz80a motif 22a005 signature agilisys industrie sara siège social angle na rue ibn aisha boulevard abdelkrim el khattabi millimètre pari haan étage appât nana gueulez amarrakech tu +212 (0) 999 99 6161 f +212 (0) 999 999 130 sara capital 500.000 000 des rcna35 33 if na 3939333 tina 3939 cnss:939 mt-103-stp 2838383393 et point pote trot cc cs con instance type and transmission de original receive from

# %% [markdown]
# <h1 id ="spacy">Text Preprocessing with spaCy</h1>

# %%
#Now we ll do preprocessing using mainly spacy
import spacy
#load only french and english models tokenizers
nlp_en = spacy.load("en_core_web_sm", disable=['parser', 'tagger', 'ner'])
nlp_fr = spacy.load("fr_core_news_sm", disable=['parser', 'tagger', 'ner'])

def spacy_preprocessing(text,lowercase=True,stopw=True,punctuation=True,alphabetic=True,lemmatize=True,):
    if detect(text)=="en":
        nlp = nlp_en
    else :
        nlp = nlp_fr
    if lowercase:
        text = text.lower()
    remove_accented_chars(text)
    #tokenize with spacy's default tokenizer
    tokens = nlp(text)
    if stopw :
        tokens = [token for token in tokens if not token.is_stop]
    if lemmatize :
        tokens = [token.lemma_.strip() for token in tokens]
    if punctuation :
        tokens = [re.sub('<[^>]*>', '', token) for token in tokens]
    if alphabetic:
        tokens = [re.sub('[\W]+','',token) for token in tokens]
    return ' '.join(word for word in tokens)

file = 'C:/Users/PC2/Downloads/test-ex.txt'
f=open(file,'r')
data = f.read()
print(spacy_preprocessing(data,lowercase=False))
# Out:
#  Gisevciconia  aero solutions  Objet  ordre virement  monsieur   dÃ  bit compte  _ rib  022 222 222 172 22 29576475 53  swt  agilisy aero solution  SWIFT  agilamcxx   virer montant  89 25000 Dirhams  quatrevingtneuf Dirhams     profit  CARLEX export Switzerland  IBAN  ch35 0483 555 555 0266600 0  SWIFT  creschzz80a  Motif  22A005  Signature   agilisy industrier sarl  SiÃ  ge social  Angle nÂ degré 2 rue ibn aicha bd Abdelkrim el khattabi imm Paris 2Â degré â  ã  tage appt nâ degré 23 gueliz âmarrakech  t  212  0  999 99 6161 l f  212  0  999 999 130   sarl capital 500000 000 dhs  RCNÂ degré 35 33  IF nâ degré 3939333  tpnâ degré 3939  cnss939  mt103stp 2838383393  mt Print   poet trot ccc cs econ instance type and transmission   Original received from

# %% [markdown]
# <h1 id ="ner">Definig NER for nltk and spacy</h1>

# %%
import spacy

# %%
def ner_nltk(text):
    assert detect(text) =='en' 'text should be english to be parsed with nltk'
    tokens = word_tokenize(text)
    tagged_tokens  = nltk.pos_tag(tokens)
    chunked = nltk.ne_chunk(tagged_tokens)
    for chunk in chunked : 
        if hasattr(chunk,"label") and chunk.label == "NE":
            print(chunk)

# %%
def ner_spacy(text):
    if detect(text) == "en":
        ner  = spacy.load("en_core_web_sm",disable=["tagger","parser"])
    else:
        ner  = spacy.load("fr_core_news_sm",disable=["tagger","parser"])
    labels = ner.get_pipe("ner").labels
    return ner(text).ents,labels

# %% [markdown]
# <h1 id ="comp">Comparing results before\after preprocessing</h1>

# %%
#preprocessed_nltk=text_preprocessing(data)
#ner_spacy(preprocessed_nltk)

# %% [markdown]
# <h2 id="param">Testing preprocessing filters</h2>

# %%
from itertools import chain , combinations
def powerset(iterable): # return all possible subsets of iterable
    s = list(iterable)
    return list(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))

list_of_params=["accented","stopw","punctuation","lowercase","lemmatize","spelling","expand_contraction","urls"] 
dict_of_params=dict.fromkeys(list_of_params,[True])

def filter_combinations(params):#return all the possible filter combinations, param; list of parametrs with a default value
    list_of_combs = []
    combs=powerset([i for i in range(len(params)) ])
    for comb in combs:
        initial_conf = [True for i in range(len(params))]
        if len(comb)==0 :
            list_of_combs.append(initial_conf)
        else:
            for i in comb:
                initial_conf[i]=False
            list_of_combs.append(initial_conf)
    return list_of_combs

# %%
import pandas as pd 
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
columns = []
columns.extend(list_of_params)
ff=filter_combinations(list_of_params)#all possible filter combinations
def results(text,preprocessing_function):
    table=[]
    labels = ner_spacy(text)[1]
    columns.extend(labels)
    for comb in ff:#comb is a combinations of active filters 
        preprocessed_text=preprocessing_function(text,*comb)
        entities = ner_spacy(preprocessed_text)[0]
        dictionn = dict.fromkeys(labels,0)
        for ent in entities:
            for key in dictionn.keys():
                if ent.label_==key:
                    dictionn[key]+=1
        comb.extend(dictionn.values())
        table.append(comb)       
    return pd.DataFrame(table,columns=columns)

# %%
results(data,text_preprocessing)

#french NER in spaCy has only  4 labels
# Out:
# c:\Users\PC2\anaconda3\lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
#      accented  stopw  punctuation  lowercase  lemmatize  spelling  \
# 0        True   True         True       True       True      True
# 1       False   True         True       True       True      True
# 2        True  False         True       True       True      True
# 3        True   True        False       True       True      True
# 4        True   True         True      False       True      True
# 5        True   True         True       True      False      True
# 6        True   True         True       True       True     False
# 7        True   True         True       True       True      True
# 8        True   True         True       True       True      True
# 9       False  False         True       True       True      True
# 10      False   True        False       True       True      True
# 11      False   True         True      False       True      True
# 12      False   True         True       True      False      True
# 13      False   True         True       True       True     False
# 14      False   True         True       True       True      True
# 15      False   True         True       True       True      True
# 16       True  False        False       True       True      True
# 17       True  False         True      False       True      True
# 18       True  False         True       True      False      True
# 19       True  False         True       True       True     False
# 20       True  False         True       True       True      True
# 21       True  False         True       True       True      True
# 22       True   True        False      False       True      True
# 23       True   True        False       True      False      True
# 24       True   True        False       True       True     False
# 25       True   True        False       True       True      True
# 26       True   True        False       True       True      True
# 27       True   True         True      False      False      True
# 28       True   True         True      False       True     False
# 29       True   True         True      False       True      True
# 30       True   True         True      False       True      True
# 31       True   True         True       True      False     False
# 32       True   True         True       True      False      True
# 33       True   True         True       True      False      True
# 34       True   True         True       True       True     False
# 35       True   True         True       True       True     False
# 36       True   True         True       True       True      True
# 37      False  False        False       True       True      True
# 38      False  False         True      False       True      True
# 39      False  False         True       True      False      True
# 40      False  False         True       True       True     False
# 41      False  False         True       True       True      True
# 42      False  False         True       True       True      True
# 43      False   True        False      False       True      True
# 44      False   True        False       True      False      True
# 45      False   True        False       True       True     False
# 46      False   True        False       True       True      True
# 47      False   True        False       True       True      True
# 48      False   True         True      False      False      True
# 49      False   True         True      False       True     False
# 50      False   True         True      False       True      True
# 51      False   True         True      False       True      True
# 52      False   True         True       True      False     False
# 53      False   True         True       True      False      True
# 54      False   True         True       True      False      True
# 55      False   True         True       True       True     False
# 56      False   True         True       True       True     False
# 57      False   True         True       True       True      True
# 58       True  False        False      False       True      True
# 59       True  False        False       True      False      True
# 60       True  False        False       True       True     False
# 61       True  False        False       True       True      True
# 62       True  False        False       True       True      True
# 63       True  False         True      False      False      True
# 64       True  False         True      False       True     False
# 65       True  False         True      False       True      True
# 66       True  False         True      False       True      True
# 67       True  False         True       True      False     False
# 68       True  False         True       True      False      True
# 69       True  False         True       True      False      True
# 70       True  False         True       True       True     False
# 71       True  False         True       True       True     False
# 72       True  False         True       True       True      True
# 73       True   True        False      False      False      True
# 74       True   True        False      False       True     False
# 75       True   True        False      False       True      True
# 76       True   True        False      False       True      True
# 77       True   True        False       True      False     False
# 78       True   True        False       True      False      True
# 79       True   True        False       True      False      True
# 80       True   True        False       True       True     False
# 81       True   True        False       True       True     False
# 82       True   True        False       True       True      True
# 83       True   True         True      False      False     False
# 84       True   True         True      False      False      True
# 85       True   True         True      False      False      True
# 86       True   True         True      False       True     False
# 87       True   True         True      False       True     False
# 88       True   True         True      False       True      True
# 89       True   True         True       True      False     False
# 90       True   True         True       True      False     False
# 91       True   True         True       True      False      True
# 92       True   True         True       True       True     False
# 93      False  False        False      False       True      True
# 94      False  False        False       True      False      True
# 95      False  False        False       True       True     False
# 96      False  False        False       True       True      True
# 97      False  False        False       True       True      True
# 98      False  False         True      False      False      True
# 99      False  False         True      False       True     False
# 100     False  False         True      False       True      True
# 101     False  False         True      False       True      True
# 102     False  False         True       True      False     False
# 103     False  False         True       True      False      True
# 104     False  False         True       True      False      True
# 105     False  False         True       True       True     False
# 106     False  False         True       True       True     False
# 107     False  False         True       True       True      True
# 108     False   True        False      False      False      True
# 109     False   True        False      False       True     False
# 110     False   True        False      False       True      True
# 111     False   True        False      False       True      True
# 112     False   True        False       True      False     False
# 113     False   True        False       True      False      True
# 114     False   True        False       True      False      True
# 115     False   True        False       True       True     False
# 116     False   True        False       True       True     False
# 117     False   True        False       True       True      True
# 118     False   True         True      False      False     False
# 119     False   True         True      False      False      True
# 120     False   True         True      False      False      True
# 121     False   True         True      False       True     False
# 122     False   True         True      False       True     False
# 123     False   True         True      False       True      True
# 124     False   True         True       True      False     False
# 125     False   True         True       True      False     False
# 126     False   True         True       True      False      True
# 127     False   True         True       True       True     False
# 128      True  False        False      False      False      True
# 129      True  False        False      False       True     False
# 130      True  False        False      False       True      True
# 131      True  False        False      False       True      True
# 132      True  False        False       True      False     False
# 133      True  False        False       True      False      True
# 134      True  False        False       True      False      True
# 135      True  False        False       True       True     False
# 136      True  False        False       True       True     False
# 137      True  False        False       True       True      True
# 138      True  False         True      False      False     False
# 139      True  False         True      False      False      True
# 140      True  False         True      False      False      True
# 141      True  False         True      False       True     False
# 142      True  False         True      False       True     False
# 143      True  False         True      False       True      True
# 144      True  False         True       True      False     False
# 145      True  False         True       True      False     False
# 146      True  False         True       True      False      True
# 147      True  False         True       True       True     False
# 148      True   True        False      False      False     False
# 149      True   True        False      False      False      True
# 150      True   True        False      False      False      True
# 151      True   True        False      False       True     False
# 152      True   True        False      False       True     False
# 153      True   True        False      False       True      True
# 154      True   True        False       True      False     False
# 155      True   True        False       True      False     False
# 156      True   True        False       True      False      True
# 157      True   True        False       True       True     False
# 158      True   True         True      False      False     False
# 159      True   True         True      False      False     False
# 160      True   True         True      False      False      True
# 161      True   True         True      False       True     False
# 162      True   True         True       True      False     False
# 163     False  False        False      False      False      True
# 164     False  False        False      False       True     False
# 165     False  False        False      False       True      True
# 166     False  False        False      False       True      True
# 167     False  False        False       True      False     False
# 168     False  False        False       True      False      True
# 169     False  False        False       True      False      True
# 170     False  False        False       True       True     False
# 171     False  False        False       True       True     False
# 172     False  False        False       True       True      True
# 173     False  False         True      False      False     False
# 174     False  False         True      False      False      True
# 175     False  False         True      False      False      True
# 176     False  False         True      False       True     False
# 177     False  False         True      False       True     False
# 178     False  False         True      False       True      True
# 179     False  False         True       True      False     False
# 180     False  False         True       True      False     False
# 181     False  False         True       True      False      True
# 182     False  False         True       True       True     False
# 183     False   True        False      False      False     False
# 184     False   True        False      False      False      True
# 185     False   True        False      False      False      True
# 186     False   True        False      False       True     False
# 187     False   True        False      False       True     False
# 188     False   True        False      False       True      True
# 189     False   True        False       True      False     False
# 190     False   True        False       True      False     False
# 191     False   True        False       True      False      True
# 192     False   True        False       True       True     False
# 193     False   True         True      False      False     False
# 194     False   True         True      False      False     False
# 195     False   True         True      False      False      True
# 196     False   True         True      False       True     False
# 197     False   True         True       True      False     False
# 198      True  False        False      False      False     False
# 199      True  False        False      False      False      True
# 200      True  False        False      False      False      True
# 201      True  False        False      False       True     False
# 202      True  False        False      False       True     False
# 203      True  False        False      False       True      True
# 204      True  False        False       True      False     False
# 205      True  False        False       True      False     False
# 206      True  False        False       True      False      True
# 207      True  False        False       True       True     False
# 208      True  False         True      False      False     False
# 209      True  False         True      False      False     False
# 210      True  False         True      False      False      True
# 211      True  False         True      False       True     False
# 212      True  False         True       True      False     False
# 213      True   True        False      False      False     False
# 214      True   True        False      False      False     False
# 215      True   True        False      False      False      True
# 216      True   True        False      False       True     False
# 217      True   True        False       True      False     False
# 218      True   True         True      False      False     False
# 219     False  False        False      False      False     False
# 220     False  False        False      False      False      True
# 221     False  False        False      False      False      True
# 222     False  False        False      False       True     False
# 223     False  False        False      False       True     False
# 224     False  False        False      False       True      True
# 225     False  False        False       True      False     False
# 226     False  False        False       True      False     False
# 227     False  False        False       True      False      True
# 228     False  False        False       True       True     False
# 229     False  False         True      False      False     False
# 230     False  False         True      False      False     False
# 231     False  False         True      False      False      True
# 232     False  False         True      False       True     False
# 233     False  False         True       True      False     False
# 234     False   True        False      False      False     False
# 235     False   True        False      False      False     False
# 236     False   True        False      False      False      True
# 237     False   True        False      False       True     False
# 238     False   True        False       True      False     False
# 239     False   True         True      False      False     False
# 240      True  False        False      False      False     False
# 241      True  False        False      False      False     False
# 242      True  False        False      False      False      True
# 243      True  False        False      False       True     False
# 244      True  False        False       True      False     False
# 245      True  False         True      False      False     False
# 246      True   True        False      False      False     False
# 247     False  False        False      False      False     False
# 248     False  False        False      False      False     False
# 249     False  False        False      False      False      True
# 250     False  False        False      False       True     False
# 251     False  False        False       True      False     False
# 252     False  False         True      False      False     False
# 253     False   True        False      False      False     False
# 254      True  False        False      False      False     False
# 255     False  False        False      False      False     False
#
#      expand_contraction   urls  LOC  MISC  ORG  PER
# 0                  True   True    0     3    2    2
# 1                  True   True    1     3    2    1
# 2                  True   True    1     3    0    4
# 3                  True   True    0     2    2    3
# 4                  True   True    2     4    2    3
# 5                  True   True    0     4    0    2
# 6                  True   True    0     0    5    0
# 7                 False   True    0     3    2    2
# 8                  True  False    0     3    2    2
# 9                  True   True    2     3    0    3
# 10                 True   True    1     3    3    1
# 11                 True   True    2     3    5    1
# 12                 True   True    1     4    0    1
# 13                 True   True    1     2    3    2
# 14                False   True    1     3    2    1
# 15                 True  False    1     3    2    1
# 16                 True   True    1     2    1    3
# 17                 True   True    2     4    1    4
# 18                 True   True    1     4    0    3
# 19                 True   True    2     2    1    4
# 20                False   True    1     3    0    4
# 21                 True  False    1     3    0    4
# 22                 True   True    1     4    2    3
# 23                 True   True    0     3    0    2
# 24                 True   True    0     0    2    0
# 25                False   True    0     2    2    3
# 26                 True  False    0     2    2    3
# 27                 True   True    2    10    1    3
# 28                 True   True    0     0    5    0
# 29                False   True    2     4    2    3
# 30                 True  False    2     4    2    3
# 31                 True   True    0     0    5    0
# 32                False   True    0     4    0    2
# 33                 True  False    0     4    0    2
# 34                False   True    0     0    5    0
# 35                 True  False    1     2    2    2
# 36                False  False    0     3    2    2
# 37                 True   True    2     3    2    2
# 38                 True   True    2     3    4    3
# 39                 True   True    1     4    0    2
# 40                 True   True    2     2    2    3
# 41                False   True    2     3    0    3
# 42                 True  False    2     3    0    3
# 43                 True   True    1     3    5    1
# 44                 True   True    1     4    1    1
# 45                 True   True    2     4    2    2
# 46                False   True    1     3    3    1
# 47                 True  False    1     3    3    1
# 48                 True   True    2     8    4    3
# 49                 True   True    0     0    6    0
# 50                False   True    2     3    5    1
# 51                 True  False    2     3    5    1
# 52                 True   True    1     1    2    2
# 53                False   True    1     4    0    1
# 54                 True  False    1     4    0    1
# 55                False   True    0     0    7    0
# 56                 True  False    1     2    3    2
# 57                False  False    1     3    2    1
# 58                 True   True    1     4    2    3
# 59                 True   True    1     3    0    3
# 60                 True   True    3     2    2    2
# 61                False   True    1     2    1    3
# 62                 True  False    1     2    1    3
# 63                 True   True    5     9    1    2
# 64                 True   True    2     7    1    3
# 65                False   True    2     4    1    4
# 66                 True  False    2     4    1    4
# 67                 True   True    2     1    1    3
# 68                False   True    1     4    0    3
# 69                 True  False    1     4    0    3
# 70                False   True    2     2    1    4
# 71                 True  False    2     2    1    4
# 72                False  False    1     3    0    4
# 73                 True   True    2    10    1    3
# 74                 True   True    3     7    2    2
# 75                False   True    1     4    2    3
# 76                 True  False    1     4    2    3
# 77                 True   True    2     2    1    1
# 78                False   True    0     3    0    2
# 79                 True  False    0     3    0    2
# 80                False   True    0     0    2    0
# 81                 True  False    0     0    2    0
# 82                False  False    0     2    2    3
# 83                 True   True    0     0    7    0
# 84                False   True    2    10    1    3
# 85                 True  False    2    10    1    3
# 86                False   True    0     0    5    0
# 87                 True  False    0     0    5    0
# 88                False  False    2     4    2    3
# 89                False   True    0     0    5    0
# 90                 True  False    1     2    1    2
# 91                False  False    0     4    0    2
# 92                False  False    1     2    2    2
# 93                 True   True    1     3    5    2
# 94                 True   True    1     4    1    2
# 95                 True   True    3     4    2    2
# 96                False   True    2     3    2    2
# 97                 True  False    2     3    2    2
# 98                 True   True    5     7    4    3
# 99                 True   True    6     5    2    2
# 100               False   True    2     3    4    3
# 101                True  False    2     3    4    3
# 102                True   True    1     1    2    2
# 103               False   True    1     4    0    2
# 104                True  False    1     4    0    2
# 105               False   True    2     2    2    3
# 106                True  False    2     2    2    3
# 107               False  False    2     3    0    3
# 108                True   True    2     7    3    4
# 109                True   True    5     4    4    2
# 110               False   True    1     3    5    1
# 111                True  False    1     3    5    1
# 112                True   True    2     2    1    2
# 113               False   True    1     4    1    1
# 114                True  False    1     4    1    1
# 115               False   True    2     4    2    2
# 116                True  False    2     4    2    2
# 117               False  False    1     3    3    1
# 118                True   True    0     0    7    0
# 119               False   True    2     8    4    3
# 120                True  False    2     8    4    3
# 121               False   True    0     0    6    0
# 122                True  False    5     5    2    3
# 123               False  False    2     3    5    1
# 124               False   True    0     0    7    0
# 125                True  False    1     1    2    2
# 126               False  False    1     4    0    1
# 127               False  False    0     0    7    0
# 128                True   True    5     8    1    2
# 129                True   True    3     7    2    2
# 130               False   True    1     4    2    3
# 131                True  False    1     4    2    3
# 132                True   True    3     1    1    2
# 133               False   True    1     3    0    3
# 134                True  False    1     3    0    3
# 135               False   True    3     2    2    2
# 136                True  False    3     2    2    2
# 137               False  False    1     2    1    3
# 138                True   True    5    12    2    4
# 139               False   True    5     9    1    2
# 140                True  False    5     9    1    2
# 141               False   True    2     7    1    3
# 142                True  False    2     7    1    3
# 143               False  False    2     4    1    4
# 144               False   True    2     1    1    3
# 145                True  False    2     1    1    3
# 146               False  False    1     4    0    3
# 147               False  False    2     2    1    4
# 148                True   True    0     0    9    0
# 149               False   True    2    10    1    3
# 150                True  False    2    10    1    3
# 151               False   True    0     0    6    0
# 152                True  False    0     0    6    0
# 153               False  False    1     4    2    3
# 154               False   True    0     0    2    0
# 155                True  False    2     2    1    1
# 156               False  False    0     3    0    2
# 157               False  False    0     0    2    0
# 158               False   True    0     0    7    0
# 159                True  False    0     0    7    0
# 160               False  False    2    10    1    3
# 161               False  False    0     0    5    0
# 162               False  False    1     2    1    2
# 163                True   True    5     6    3    4
# 164                True   True    6     5    4    1
# 165               False   True    1     3    5    2
# 166                True  False    1     3    5    2
# 167                True   True    2     2    1    2
# 168               False   True    1     4    1    2
# 169                True  False    1     4    1    2
# 170               False   True    3     4    2    2
# 171                True  False    3     4    2    2
# 172               False  False    2     3    2    2
# 173                True   True    7    10    2    4
# 174               False   True    5     7    4    3
# 175                True  False    5     7    4    3
# 176               False   True    6     5    2    2
# 177                True  False    6     5    2    2
# 178               False  False    2     3    4    3
# 179               False   True    1     1    2    2
# 180                True  False    1     1    2    2
# 181               False  False    1     4    0    2
# 182               False  False    2     2    2    3
# 183                True   True    0     0    9    0
# 184               False   True    2     7    3    4
# 185                True  False    2     7    3    4
# 186               False   True    0     0    6    0
# 187                True  False    0     0    6    0
# 188               False  False    1     3    5    1
# 189               False   True    0     0    6    0
# 190                True  False    2     2    1    2
# 191               False  False    1     4    1    1
# 192               False  False    0     0    6    0
# 193               False   True    0     0    7    0
# 194                True  False    0     0    7    0
# 195               False  False    2     8    4    3
# 196               False  False    0     0    6    0
# 197               False  False    1     1    2    2
# 198                True   True    6    12    2    5
# 199               False   True    5     8    1    2
# 200                True  False    5     8    1    2
# 201               False   True    3     7    2    2
# 202                True  False    3     7    2    2
# 203               False  False    1     4    2    3
# 204               False   True    3     1    1    2
# 205                True  False    3     1    1    2
# 206               False  False    1     3    0    3
# 207               False  False    3     2    2    2
# 208               False   True    5    12    2    4
# 209                True  False    5    12    2    4
# 210               False  False    5     9    1    2
# 211               False  False    2     7    1    3
# 212               False  False    2     1    1    3
# 213               False   True    0     0    9    0
# 214                True  False    0     0    9    0
# 215               False  False    2    10    1    3
# 216               False  False    0     0    6    0
# 217               False  False    0     0    2    0
# 218               False  False    0     0    7    0
# 219                True   True    8    10    2    4
# 220               False   True    5     6    3    4
# 221                True  False    5     6    3    4
# 222               False   True    6     5    4    1
# 223                True  False    6     5    4    1
# 224               False  False    1     3    5    2
# 225               False   True    2     2    1    2
# 226                True  False    2     2    1    2
# 227               False  False    1     4    1    2
# 228               False  False    3     4    2    2
# 229               False   True    7    10    2    4
# 230                True  False    7    10    2    4
# 231               False  False    5     7    4    3
# 232               False  False    6     5    2    2
# 233               False  False    1     1    2    2
# 234               False   True    0     0    9    0
# 235                True  False    0     0    9    0
# 236               False  False    2     7    3    4
# 237               False  False    5     4    4    2
# 238               False  False    0     0    6    0
# 239               False  False    0     0    7    0
# 240               False   True    6    12    2    5
# 241                True  False    6    12    2    5
# 242               False  False    5     8    1    2
# 243               False  False    3     7    2    2
# 244               False  False    3     1    1    2
# 245               False  False    5    12    2    4
# 246               False  False    0     0    9    0
# 247               False   True    8    10    2    4
# 248                True  False    8    10    2    4
# 249               False  False    5     6    3    4
# 250               False  False    6     5    4    1
# 251               False  False    2     2    1    2
# 252               False  False    7    10    2    4
# 253               False  False    0     0    9    0
# 254               False  False    6    12    2    5
# 255               False  False    8    10    2    4

# %%
text = text_preprocessing('i am Achraf from morocco Text is the text from wich we extract the entities params : a list of boolean to determine the filters we want to activate("accented","stopw","punctuation","lowercase","lemmatize","spelling","expand_contraction","urls"',*[True,True,True,False])
ner_spacy(text)
# Out:
# c:\Users\PC2\anaconda3\lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# ((morocco Text,),
#  ('CARDINAL',
#   'DATE',
#   'EVENT',
#   'FAC',
#   'GPE',
#   'LANGUAGE',
#   'LAW',
#   'LOC',
#   'MONEY',
#   'NORP',
#   'ORDINAL',
#   'ORG',
#   'PERCENT',
#   'PERSON',
#   'PRODUCT',
#   'QUANTITY',
#   'TIME',
#   'WORK_OF_ART'))
